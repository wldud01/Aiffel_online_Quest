# %% [markdown]
# ## 프로젝트: SentencePiece 사용하기

# %%
# 모듈 불러오기
import tensorflow as tf
import numpy as np
import matplotlib as plt
import konlpy

print(tf.__version__)
print(np.__version__)
print(plt.__version__)
print(konlpy.__version__)
# Out:
# 2.6.0
# 1.21.4
# 3.4.3
# 0.5.2

# %%
import os

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# %matplotlib inline
import os
path_to_file = os.getenv('HOME')+'/aiffel/sp_tokenizer/data/korean-english-park.train.ko'

with open(path_to_file, "r") as f:
    raw = f.read().splitlines()

print("Data Size:", len(raw))

print("Example:")
for sen in raw[0:100][::20]: print(">>", sen)
# Out:
# Data Size: 94123
# Example:
# >> 개인용 컴퓨터 사용의 상당 부분은 "이것보다 뛰어날 수 있느냐?"
# >> 북한의 핵무기 계획을 포기하도록 하려는 압력이 거세지고 있는 가운데, 일본과 북한의 외교관들이 외교 관계를 정상화하려는 회담을 재개했다.
# >> "경호 로보트가 침입자나 화재를 탐지하기 위해서 개인적으로, 그리고 전문적으로 사용되고 있습니다."
# >> 수자원부 당국은 논란이 되고 있고, 막대한 비용이 드는 이 사업에 대해 내년에 건설을 시작할 계획이다.
# >> 또한 근력 운동은 활발하게 걷는 것이나 최소한 20분 동안 뛰는 것과 같은 유산소 활동에서 얻는 운동 효과를 심장과 폐에 주지 않기 때문에, 연구학자들은 근력 운동이 심장에 큰 영향을 미치는지 여부에 대해 논쟁을 해왔다.

# %%
min_len = 999
max_len = 0
sum_len = 0

for sen in raw:
    length = len(sen)
    if min_len > length: 
        min_len = length
    if max_len < length: 
        max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(raw))

sentence_length = np.zeros((max_len), dtype=int)

for sen in raw:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 1
# 문장의 최장 길이: 377
# 문장의 평균 길이: 60

# %%
def check_sentence_with_length(raw, length):
    count = 0
    
    for sen in raw:
        if len(sen) == length:
            print(sen)
            count += 1
            if count > 100: return

# 이상치 확인하기
check_sentence_with_length(raw, 1)
# Out:
# ’

# %%
# outlier 추출
for idx, _sum in enumerate(sentence_length):
    # 문장의 수가 1500을 초과하는 문장 길이를 추출합니다.
    if _sum > 1500:
        print("Outlier Index:", idx+1)
# Out:
# Outlier Index: 11
# Outlier Index: 19
# Outlier Index: 21

# %%
min_len = 999
max_len = 0
sum_len = 0

# 특정 길이 제거
cleaned_corpus = list(set(raw))  # set를 사용해서 중복을 제거합니다.
print("Data Size:", len(cleaned_corpus))

for sen in cleaned_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(cleaned_corpus))

sentence_length = np.zeros((max_len), dtype=int)

for sen in cleaned_corpus:   # 중복이 제거된 코퍼스 기준
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# Data Size: 77591
# 문장의 최단 길이: 1
# 문장의 최장 길이: 377
# 문장의 평균 길이: 64

# %%
max_len = 150
min_len = 10

# 길이 조건에 맞는 문장만 선택합니다.
filtered_corpus = [s for s in cleaned_corpus if (len(s) < max_len) & (len(s) >= min_len)]

# 분포도를 다시 그려봅니다.
sentence_length = np.zeros((max_len), dtype=int)

for sen in filtered_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()

# %%
split_corpus = []

# 공백 추출 방식
for kor in filtered_corpus:
    split_corpus.append(kor.split())

# %%
def tokenize(corpus):  # corpus: Tokenized Sentence's List
    tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    tokenizer.fit_on_texts(corpus)

    tensor = tokenizer.texts_to_sequences(corpus)
    
    # padding
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

    return tensor, tokenizer

# %%
# SentencePiece unigram
import sentencepiece as spm
import os
temp_file = os.getenv('HOME')+'/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp'

vocab_size = 8000

# 정제한 corpus를 가지고 temp file에 write
with open(temp_file, 'w') as f:
    for row in filtered_corpus:   # 이전에 나왔던 정제했던 corpus를 활용해서 진행해야 합니다.
        f.write(str(row) + '\n')

spm.SentencePieceTrainer.Train(
    '--input={} --model_prefix=korean_spm --vocab_size={}'.format(temp_file, vocab_size)    
)
#위 Train에서  --model_type = unigram이 디폴트 적용되어 있습니다. --model_type = bpe로 옵션을 주어 변경할 수 있습니다.

# !ls -l korean_spm*
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp --model_prefix=korean_spm --vocab_size=8000
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp
#   input_format:
#   model_prefix: korean_spm
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp
# trainer_interface.cc(385) LOG(INFO) Loaded all 76908 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4996369
# trainer_interface.cc(477) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1317
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 76908 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 174340 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 76908
# trainer_interface.cc(537) LOG(INFO) Done! 237965
# unigram_model_trainer.cc(489) LOG(INFO) Using 237965 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=92555 obj=14.853 num_tokens=523272 num_tokens/piece=5.65363
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=82083 obj=13.516 num_tokens=525776 num_tokens/piece=6.40542
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=61555 obj=13.5533 num_tokens=546907 num_tokens/piece=8.88485
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=61506 obj=13.5101 num_tokens=547350 num_tokens/piece=8.89913
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=46126 obj=13.6926 num_tokens=575369 num_tokens/piece=12.4739
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=46126 obj=13.6493 num_tokens=575466 num_tokens/piece=12.476
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=34594 obj=13.8894 num_tokens=606014 num_tokens/piece=17.5179
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=34594 obj=13.8387 num_tokens=606012 num_tokens/piece=17.5178
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=25945 obj=14.1301 num_tokens=637532 num_tokens/piece=24.5724
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=25945 obj=14.0747 num_tokens=637568 num_tokens/piece=24.5738
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=19458 obj=14.4091 num_tokens=670960 num_tokens/piece=34.4825
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=19458 obj=14.3468 num_tokens=670999 num_tokens/piece=34.4845
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=14593 obj=14.7196 num_tokens=705636 num_tokens/piece=48.3544
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=14593 obj=14.648 num_tokens=705645 num_tokens/piece=48.355
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=10944 obj=15.0875 num_tokens=741620 num_tokens/piece=67.765
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=10944 obj=15.007 num_tokens=741624 num_tokens/piece=67.7654
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=8800 obj=15.3757 num_tokens=769363 num_tokens/piece=87.4276
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=8800 obj=15.307 num_tokens=769367 num_tokens/piece=87.4281
# trainer_interface.cc(615) LOG(INFO) Saving model: korean_spm.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: korean_spm.vocab
# -rw-r--r-- 1 root root 376816 Dec 27 03:27 korean_spm.model
# -rw-r--r-- 1 root root 146213 Dec 27 03:27 korean_spm.vocab

# %%
# SentencePiece bpe
temp_file = os.getenv('HOME')+'/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp'

vocab_size = 8000

# 정제한 corpus를 가지고 temp file에 write
with open(temp_file, 'w') as f:
    for row in filtered_corpus: 
        f.write(str(row) + '\n')

spm.SentencePieceTrainer.Train(
    '--input={} --model_prefix=korean_spm_bpe --vocab_size={} --model_type=bpe'.format(temp_file, vocab_size)
)
#위 Train에서  --model_type = unigram이 디폴트 적용되어 있습니다. --model_type = bpe로 옵션을 주어 변경할 수 있습니다.

# !ls -l korean_spm_bpe*
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp --model_prefix=korean_spm_bpe --vocab_size=8000 --model_type=bpe
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp
#   input_format:
#   model_prefix: korean_spm_bpe
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp
# trainer_interface.cc(385) LOG(INFO) Loaded all 76908 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4996369
# trainer_interface.cc(477) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1317
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 76908 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 76908
# trainer_interface.cc(537) LOG(INFO) Done! 237965
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=37043 min_freq=188
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10526 size=20 all=64102 active=6239 piece=▁가
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7586 size=40 all=66979 active=9116 piece=▁일
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5712 size=60 all=69013 active=11150 piece=▁하
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4404 size=80 all=71006 active=13143 piece=▁해
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3904 size=100 all=72666 active=14803 piece=▁결
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3872 min_freq=147
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3422 size=120 all=74308 active=5232 piece=▁반
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3011 size=140 all=76157 active=7081 piece=들을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=

# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=68 size=5660 all=213397 active=11180 piece=▁합병
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=68 size=5680 all=213501 active=11284 piece=▁역사적인
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=67 size=5700 all=213953 active=11736 piece=▁52
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=67 min_freq=21
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=67 size=5720 all=214172 active=10906 piece=카르타
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=67 size=5740 all=214286 active=11020 piece=▁뉴욕에서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=5760 all=214415 active=11149 piece=뉴스
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=5780 all=214838 active=11572 piece=▁55
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=5800 all=215100 active=11834 piece=샤라포
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=66 min_freq=21
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=66 size=5820 all=215130 active=10783 piece=마빈라덴
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=5840 all=215388 active=11041 piece=아프
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=5860 all=215679 active=11332 piece=▁비공
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=5880 all=215966 active=11619 piece=▁ABC
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=65 size=5900 all=215993 active=11646 piece=▁수백명의
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=65 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=64 size=5920 all=216173 active=10980 piece=▁메릴
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=64 size=5940 all=216473 active=11280 piece=페인을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=64 size=5960 all=216520 active=11327 piece=▁소프트웨어
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=5980 all=216830 active=11637 piece=▁감지
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=6000 all=217104 active=11911 piece=▁알라
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=63 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=6020 all=217441 active=11180 piece=▁두바이
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=63 size=6040 all=217551 active=11290 piece=▁수석대표
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=6060 all=217823 active=11562 piece=▁결코
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=6080 all=217997 active=11736 piece=▁영웅
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=6100 all=218280 active=12019 piece=경찰이
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=62 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=6120 all=218427 active=11055 piece=▁완전한
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62 size=6140 all=218473 active=11101 piece=▁블라디미르
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=6160 all=218689 active=11317 piece=매우
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=6180 all=219053 active=11681 piece=▁년간
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=6200 all=219217 active=11845 piece=▁촉진
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=61 min_freq=20
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=61 size=6220 all=219356 active=11078 piece=▁지하철
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=6240 all=219520 active=11242 piece=▁좁
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=6260 all=219914 active=11636 piece=▁골든
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=6280 all=220149 active=11871 piece=▁왕실
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=6300 all=220250 active=11972 piece=▁오늘날
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=60 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=60 size=6320 all=220293 active=11052 piece=▁공개적으로
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=59 size=6340 all=220631 active=11390 piece=ush
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=59 size=6360 all=220800 active=11559 piece=▁전설
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=59 size=6380 all=220995 active=11754 piece=▁리히터
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=59 size=6400 all=221012 active=11771 piece=▁포함돼
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=59 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=58 size=6420 all=221062 active=11097 piece=IV
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=58 size=6440 all=221439 active=11474 piece=▁Se
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=58 size=6460 all=221668 active=11703 piece=▁예선
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=58 size=6480 all=221875 active=11910 piece=▁마무드
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=58 size=6500 all=221934 active=11969 piece=▁목격자들은
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=58 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=57 size=6520 all=222334 active=11497 piece=ass
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=57 size=6540 all=222608 active=11771 piece=▁상반
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=57 size=6560 all=222855 active=12018 piece=웨이트
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=57 size=6580 all=222906 active=12069 piece=▁사업을
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=57 size=6600 all=222923 active=12086 piece=▁증가했다고
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=57 min_freq=19
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=56 size=6620 all=223278 active=11502 piece=치게
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=56 size=6640 all=223554 active=11778 piece=▁맡고
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=56 size=6660 all=223785 active=12009 piece=식에서
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=56 size=6680 all=223850 active=12074 piece=▁조종사
# trainer_interface.cc(615) LOG(INFO) Saving model: korean_spm_bpe.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: korean_spm_bpe.vocab
# -rw-r--r-- 1 root root 371940 Dec 27 05:48 korean_spm_bpe.model
# -rw-r--r-- 1 root root 117142 Dec 27 05:48 korean_spm_bpe.vocab

# %% [markdown]
# ### Ready for Data

# %%
# !unzip nsmc-master.zip -d data
# Out:
# Archive:  nsmc-master.zip
# cc0670e872d4ac27bfe36c87456783004b39ef6c
#    creating: data/nsmc-master/
#   inflating: data/nsmc-master/README.md
#    creating: data/nsmc-master/code/
#   inflating: data/nsmc-master/code/crawl_ratings.py
#   inflating: data/nsmc-master/code/partition.py
#   inflating: data/nsmc-master/ratings.txt
#   inflating: data/nsmc-master/ratings_test.txt
#   inflating: data/nsmc-master/ratings_train.txt
#    creating: data/nsmc-master/raw/
#   inflating: data/nsmc-master/raw/10001.json
#   inflating: data/nsmc-master/raw/100015.json
#   inflating: data/nsmc-master/raw/10002.json
#   inflating: data/nsmc-master/raw/100021.json
#   inflating: data/nsmc-master/raw/100022.json
#   inflating: data/nsmc-master/raw/100023.json
#   inflating: data/nsmc-master/raw/100026.json
#   inflating: data/nsmc-master/raw/10003.json
#   inflating: data/nsmc-master/raw/100039.json
#   inflating: data/nsmc-master/raw/10004.json
#   inflating: data/nsmc-master/raw/100041.json
#   inflating: data/nsmc-master/raw/10005.json
#   inflating: data/nsmc-master/raw/10006.json
#   inflating: data/nsmc-master/raw/100069.json
#   inflating: data/nsmc-master/raw/10007.json
#   inflating: data/nsmc-master/raw/100075.json
#   inflating: data/nsmc-master/raw/10008.json
#   inflating: data/nsmc-master/raw/100084.json
#   inflating: data/nsmc-master/raw/100086.json
#   inflating: data/nsmc-master/raw/100087.json
#   inflating: data/nsmc-master/raw/10009.json
#   inflating: data/nsmc-master/raw/100097.json
#   inflating: data/nsmc-master/raw/100098.json
#   inflating: data/nsmc-master/raw/100099.json
#   inflating: data/nsmc-master/raw/100100.json
#   inflating: data/nsmc-master/raw/100104.json
#   inflating: data/nsmc-master/raw/100109.json
#   inflating: data/nsmc-master/raw/10011.json
#   inflating: data/nsmc-master/raw/100110.json
#   inflating: data/nsmc-master/raw/10012.json
#   inflating: data/nsmc-master/raw/10013.json
#   inflating: data/nsmc-master/raw/10014.json
#   inflating: data/nsmc-master/raw/100145.json
#   inflating: data/nsmc-master/raw/100147.json
#   inflating: data/nsmc-master/raw/10015.json
#   inflating: data/nsmc-master/raw/10016.json
#   inflating: data/nsmc-master/raw/10017.json
#   inflating: data/nsmc-master/raw/10018.json
#   inflating: data/nsmc-master/raw/10019.json
#   inflating: data/nsmc-master/raw/10020.json
#   inflating: data/nsmc-master/raw/100203.json
#   inflating: data/nsmc-master/raw/100206.json
#   inflating: data/nsmc-master/raw/10021.json
#   inflating: data/nsmc-master/raw/10022.json
#   inflating: data/nsmc-master/raw/10023.json
#   inflating: data/nsmc-master/raw/10024.json
#   inflating: data/nsmc-master/raw/10025.json
#   inflating: data/nsmc-master/raw/10026.json
#   inflating: data/nsmc-master/raw/100269.json
#   inflating: data/nsmc-master/raw/10027.json
#   inflating: data/nsmc-master/raw/100274.json
#   inflating: data/nsmc-master/raw/10028.json
#   inflating: data/nsmc-master/raw/100280.json
#   inflating: data/nsmc-master/raw/10029.json
#   inflating: data/nsmc-master/raw/10030.json
#   inflating: data/nsmc-master/raw/100303.json
#   inflating: data/nsmc-master/raw/100304.json
#   inflating: data/nsmc-master/raw/100306.json
#   inflating: data/nsmc-master/raw/100321.json
#   inflating: data/nsmc-master/raw/10033.json
#   inflating: data/nsmc-master/raw/100337.json
#   inflating: data/nsmc-master/raw/10034.json
#   inflating: data/nsmc-master/raw/10035.json
#   inflating: data/nsmc-master/raw/100356.json
#   inflating: data/nsmc-master/raw/10036.json
#   inflating: data/nsmc-master/raw/10037.json
#   inflating: data/nsmc-master/raw/100371.json
#   inflating: data/nsmc-master/raw/100372.json
#   inflating: data/nsmc-master/raw/100376.json
#   inflating: data/nsmc-master/raw/10038.json
#   inflating: data/nsmc-master/raw/100388.json
#   inflating: data/nsmc-master/raw/10039.json
#   inflating: data/nsmc-master/raw/100392.json
#   inflating: data/nsmc-master/raw/100396.json
#   inflating: data/nsmc-master/raw/100398.json
#   inflating: data/nsmc-master/raw/100399.json
#   inflating: data/nsmc-master/raw/10040.json
#   inflating: data/nsmc-master/raw/10041.json
#   inflating: data/nsmc-master/raw/10042.json
#   inflating: data/nsmc-master/raw/10043.json
#   inflating: data/nsmc-master/raw/10044.json
#   inflating: data/nsmc-master/raw/10045.json
#   inflating: data/nsmc-master/raw/10046.json
#   inflating: data/nsmc-master/raw/10047.json
#   inflating: data/nsmc-master/raw/10048.json
#   inflating: data/nsmc-master/raw/10049.json
#   inflating: data/nsmc-master/raw/10050.json
#   inflating: data/nsmc-master/raw/10053.json
#   inflating: data/nsmc-master/raw/10054.json
#   inflating: data/nsmc-master/raw/10055.json
#   inflating: data/nsmc-master/raw/10056.json
#   inflating: data/nsmc-master/raw/100567.json
#   inflating: data/nsmc-master/raw/10057.json
#   inflating: data/nsmc-master/raw/100572.json
#   inflating: data/nsmc-master/raw/10058.json
#   inflating: data/nsmc-master/raw/100580.json
#   inflating: data/nsmc-master/raw/10059.json
#   inflating: data/nsmc-master/raw/10061.json
#   inflating: data/nsmc-master/raw/100610.json
#   inflating: data/nsmc-master/raw/100619.json
#   inflating: data/nsmc-master/raw/10062.json
#   inflating: data/nsmc-master/raw/100627.json
#   inflating: data/nsmc-master/raw/10063.json
#   inflating: data/nsmc-master/raw/100630.json
#   inflating: data/nsmc-master/raw/100631.json
#   inflating: data/nsmc-master/raw/100633.json
#   inflating: data/nsmc-master/raw/100634.json
#   inflating: data/nsmc-master/raw/100635.json
#   inflating: data/nsmc-master/raw/100636.json
#   inflating: data/nsmc-master/raw/100637.json
#   inflating: data/nsmc-master/raw/100639.json
#   inflating: data/nsmc-master/raw/10064.json
#   inflating: data/nsmc-master/raw/100642.json
#   inflating: data/nsmc-master/raw/100644.json
#   inflating: data/nsmc-master/raw/100645.json
#   inflating: data/nsmc-master/raw/100646.json
#   inflating: data/nsmc-master/raw/100648.json
#   inflating: data/nsmc-master/raw/100649.json
#   inflating: data/nsmc-master/raw/10065.json
#   inflating: data/nsmc-master/raw/100650.json
#   inflating: data/nsmc-master/raw/100651.json
#   inflating: data/nsmc-master/raw/100652.json
#   inflating: data/nsmc-master/raw/100654.json
#   inflating: data/nsmc-master/raw/100655.json
#   inflating: data/nsmc-master/raw/10066.json
#   inflating: data/nsmc-master/raw/10067.json
#   inflating: data/nsmc-master/raw/100671.json
#   inflating: data/nsmc-master/raw/100675.json
#   inflating: data/nsmc-master/raw/100676.json
#   inflating: data/nsmc-master/raw/100677.json
#   inflating: data/nsmc-master/raw/100678.json
#   inflating: data/nsmc-master/raw/10068.json
#   inflating: data/nsmc-master/raw/10069.json
#   inflating: data/nsmc-master/raw/100691.json
#   inflating: data/nsmc-master/raw/10070.json
#   inflating: data/nsmc-master/raw/10071.json
#   inflating: data/nsmc-master/raw/10072.json
#   inflating: data/nsmc-master/raw/10073.json
#   inflating: data/nsmc-master/raw/100730.json
#   inflating: data/nsmc-master/raw/10080.json
#   inflating: data/nsmc-master/raw/100801.json
#   inflating: data/nsmc-master/raw/100802.json
#   inflating: data/nsmc-master/raw/10081.json
#   inflating: data/nsmc-master/raw/100815.json
#   inflating: data/nsmc-master/raw/100819.json
#   inflating: data/nsmc-master/raw/10082.json
#   inflating: data/nsmc-master/raw/100825.json
#   inflating: data/nsmc-master/raw/100827.json
#   inflating: data/nsmc-master/raw/100828.json
#   inflating: data/nsmc-master/raw/10086.json
#   inflating: data/nsmc-master/raw/10087.json
#   inflating: data/nsmc-master/raw/10088.json
#   inflating: data/nsmc-master/raw/10089.json
#   inflating: data/nsmc-master/raw/10090.json
#   inflating: data/nsmc-master/raw/100916.json
#   inflating: data/nsmc-master/raw/100919.json
#   inflating: data/nsmc-master/raw/10092.json
#   inflating: data/nsmc-master/raw/100924.json
#   inflating: data/nsmc-master/raw/100926.json
#   inflating: data/nsmc-master/raw/10093.json
#   inflating: data/nsmc-master/raw/100930.json
#   inflating: data/nsmc-master/raw/100931.json
#   inflating: data/nsmc-master/raw/100933.json
#   inflating: data/nsmc-master/raw/100934.json
#   inflating: data/nsmc-master/raw/100935.json
#   inflating: data/nsmc-master/raw/100938.json
#   inflating: data/nsmc-master/raw/10094.json
#   inflating: data/nsmc-master/raw/100946.json
#   inflating: data/nsmc-master/raw/100947.json
#   inflating: data/nsmc-master/raw/10095.json
#   inflating: data/nsmc-master/raw/100950.json
#   inflating: data/nsmc-master/raw/100951.json
#   inflating: data/nsmc-master/raw/100953.json
#   inflating: data/nsmc-master/raw/10096.json
#   inflating: data/nsmc-master/raw/100967.json
#   inflating: data/nsmc-master/raw/100973.json
#   inflating: data/nsmc-master/raw/100974.json
#   inflating: data/nsmc-master/raw/100977.json
#   inflating: data/nsmc-master/raw/100979.json
#   inflating: data/nsmc-master/raw/100982.json
#   inflating: data/nsmc-master/raw/100984.json
#   inflating: data/nsmc-master/raw/100985.json
#   inflating: data/nsmc-master/raw/100987.json
#   inflating: data/nsmc-master/raw/10099.json
#   inflating: data/nsmc-master/raw/100990.json
#   inflating: data/nsmc-master/raw/100991.json
#   inflating: data/nsmc-master/raw/100992.json
#   inflating: data/nsmc-master/raw/100994.json
#   inflating: data/nsmc-master/raw/100996.json
#   inflating: data/nsmc-master/raw/100997.json
#   inflating: data/nsmc-master/raw/10100.json
#   inflating: data/nsmc-master/raw/10101.json
#   inflating: data/nsmc-master/raw/10102.json
#   inflating: data/nsmc-master/raw/10103.json
#   inflating: data/nsmc-master/raw/101038.json
#   inflating: data/nsmc-master/raw/10104.json
#   inflating: data/nsmc-master/raw/101047.json
#   inflating: data/nsmc-master/raw/10105.json
#   inflating: data/nsmc-master/raw/101054.json
#   inflating: data/nsmc-master/raw/10106.json
#   inflating: data/nsmc-master/raw/101062.json
#   inflating: data/nsmc-master/raw/101065.json
#   inflating: data/nsmc-master/raw/10107.json
#   inflating: data/nsmc-master/raw/101088.json
#   inflating: data/nsmc-master/raw/101089.json
#   inflating: data/nsmc-master/raw/10109.json
#   inflating: data/nsmc-master/raw/101096.json
#   inflating: data/nsmc-master/raw/10110.json
#   inflating: data/nsmc-master/raw/101101.json
#   inflating: data/nsmc-master/raw/10111.json
#   inflating: data/nsmc-master/raw/101111.json
#   inflating: data/nsmc-master/raw/10112.json
#   inflating: data/nsmc-master/raw/10113.json
#   inflating: data/nsmc-master/raw/101134.json
#   inflating: data/nsmc-master/raw/10114.json
#   inflating: data/nsmc-master/raw/101143.json
#   inflating: data/nsmc-master/raw/10115.json
#   inflating: data/nsmc-master/raw/101150.json
#   inflating: data/nsmc-master/raw/101156.json
#   inflating: data/nsmc-master/raw/10116.json
#   inflating: data/nsmc-master/raw/101166.json
#   inflating: data/nsmc-master/raw/10117.json
#   inflating: data/nsmc-master/raw/101173.json
#   inflating: data/nsmc-master/raw/101174.json
#   inflating: data/nsmc-master/raw/101175.json
#   inflating: data/nsmc-master/raw/101178.json
#   inflating: data/nsmc-master/raw/10118.json
#   inflating: data/nsmc-master/raw/101180.json
#   inflating: data/nsmc-master/raw/101187.json
#   inflating: data/nsmc-master/raw/10119.json
#   inflating: data/nsmc-master/raw/10120.json
#   inflating: data/nsmc-master/raw/10121.json
#   inflating: data/nsmc-master/raw/101216.json
#   inflating: data/nsmc-master/raw/101217.json
#   inflating: data/nsmc-master/raw/101236.json
#   inflating: data/nsmc-master/raw/101237.json
#   inflating: data/nsmc-master/raw/101238.json
#   inflating: data/nsmc-master/raw/101241.json
#   inflating: data/nsmc-master/raw/101242.json
#   inflating: data/nsmc-master/raw/101248.json
#   inflating: data/nsmc-master/raw/101249.json
#   inflating: data/nsmc-master/raw/101250.json
#   inflating: data/nsmc-master/raw/101252.json
#   inflating: data/nsmc-master/raw/101253.json
#   inflating: data/nsmc-master/raw/101255.json
#   inflating: data/nsmc-master/raw/101258.json
#   inflating: data/nsmc-master/raw/101259.json
#   inflating: data/nsmc-master/raw/10126.json
#   inflating: data/nsmc-master/raw/10127.json
#   inflating: data/nsmc-master/raw/101276.json
#   inflating: data/nsmc-master/raw/10128.json
#   inflating: data/nsmc-master/raw/10130.json
#   inflating: data/nsmc-master/raw/101300.json
#   inflating: data/nsmc-master/raw/101301.json
#   inflating: data/nsmc-master/raw/101318.json
#   inflating: data/nsmc-master/raw/10132.json
#   inflating: data/nsmc-master/raw/10133.json
#   inflating: data/nsmc-master/raw/10134.json
#   inflating: data/nsmc-master/raw/10137.json
#   inflating: data/nsmc-master/raw/10138.json
#   inflating: data/nsmc-master/raw/10139.json
#   inflating: data/nsmc-master/raw/10140.json
#   inflating: data/nsmc-master/raw/10142.json
#   inflating: data/nsmc-master/raw/10143.json
#   inflating: data/nsmc-master/raw/101430.json
#   inflating: data/nsmc-master/raw/101432.json
#   inflating: data/nsmc-master/raw/101433.json
#   inflating: data/nsmc-master/raw/101435.json
#   inflating: data/nsmc-master/raw/101436.json
#   inflating: data/nsmc-master/raw/101438.json
#   inflating: data/nsmc-master/raw/101439.json
#   inflating: data/nsmc-master/raw/101440.json
#   inflating: data/nsmc-master/raw/101441.json
#   inflating: data/nsmc-master/raw/101442.json
#   inflating: data/nsmc-master/raw/101443.json
#   inflating: data/nsmc-master/raw/101445.json
#   inflating: data/nsmc-master/raw/101446.json
#   inflating: data/nsmc-master/raw/101448.json
#   inflating: data/nsmc-master/raw/10145.json
#   inflating: data/nsmc-master/raw/101451.json
#   inflating: data/nsmc-master/raw/101454.json
#   inflating: data/nsmc-master/raw/101456.json
#   inflating: data/nsmc-master/raw/101457.json
#   inflating: data/nsmc-master/raw/101458.json
#   inflating: data/nsmc-master/raw/10146.json
#   inflating: data/nsmc-master/raw/101460.json
#   inflating: data/nsmc-master/raw/101461.json
#   inflating: data/nsmc-master/raw/101462.json
#   inflating: data/nsmc-master/raw/101463.json
#   inflating: data/nsmc-master/raw/101464.json
#   inflating: data/nsmc-master/raw/101465.json
#   inflating: data/nsmc-master/raw/101468.json
#   inflating: data/nsmc-master/raw/101469.json
#   inflating: data/nsmc-master/raw/10147.json
#   inflating: data/nsmc-master/raw/101470.json
#   inflating: data/nsmc-master/raw/101471.json
#   inflating: data/nsmc-master/raw/101472.json
#   inflating: data/nsmc-master/raw/101473.json
#   inflating: data/nsmc-master/raw/101474.json
#   inflating: data/nsmc-master/raw/101475.json
#   inflating: data/nsmc-master/raw/101476.json
#   inflating: data/nsmc-master/raw/10148.json
#   inflating: data/nsmc-master/raw/101480.json
#   inflating: data/nsmc-master/raw/101483.json
#   inflating: data/nsmc-master/raw/101484.json
#   inflating: data/nsmc-master/raw/101489.json
#   inflating: data/nsmc-master/raw/10149.json
#   inflating: data/nsmc-master/raw/101490.json
#   inflating: data/nsmc-master/raw/101491.json
#   inflating: data/nsmc-master/raw/101494.json
#   inflating: data/nsmc-master/raw/101495.json
#   inflating: data/nsmc-master/raw/101498.json
#   inflating: data/nsmc-master/raw/10150.json
#   inflating: data/nsmc-master/raw/10151.json
#   inflating: data/nsmc-master/raw/10152.json
#   inflating: data/nsmc-master/raw/10153.json
#   inflating: data/nsmc-master/raw/10154.json
#   inflating: data/nsmc-master/raw/10155.json
#   inflating: data/nsmc-master/raw/10156.json
#   inflating: data/nsmc-master/raw/10157.json
#   inflating: data/nsmc-master/raw/10158.json
#   inflating: data/nsmc-master/raw/10159.json
#   inflating: data/nsmc-master/raw/10160.json
#   inflating: data/nsmc-master/raw/101606.json
#   inflating: data/nsmc-master/raw/10161.json
#   inflating: data/nsmc-master/raw/101611.json
#   inflating: data/nsmc-master/raw/101617.json
#   inflating: data/nsmc-master/raw/101618.json
#   inflating: data/nsmc-master/raw/10162.json
#   inflating: data/nsmc-master/raw/10163.json
#   inflating: data/nsmc-master/raw/101631.json
#   inflating: data/nsmc-master/raw/10164.json
#   inflating: data/nsmc-master/raw/101645.json
#   inflating: data/nsmc-master/raw/10165.json
#   inflating: data/nsmc-master/raw/10166.json
#   inflating: data/nsmc-master/raw/101662.json
#   inflating: data/nsmc-master/raw/101664.json
#   inflating: data/nsmc-master/raw/101669.json
#   inflating: data/nsmc-master/raw/10167.json
#   inflating: data/nsmc-master/raw/10168.json
#   inflating: data/nsmc-master/raw/10169.json
#   inflating: data/nsmc-master/raw/10170.json
#   inflating: data/nsmc-master/raw/101700.json
#   inflating: data/nsmc-master/raw/101707.json
#   inflating: data/nsmc-master/raw/10171.json
#   inflating: data/nsmc-master/raw/101718.json
#   inflating: data/nsmc-master/raw/10172.json
#   inflating: data/nsmc-master/raw/10173.json
#   inflating: data/nsmc-master/raw/101746.json
#   inflating: data/nsmc-master/raw/101758.json
#   inflating: data/nsmc-master/raw/10176.json
#   inflating: data/nsmc-master/raw/10177.json
#   inflating: data/nsmc-master/raw/101776.json
#   inflating: data/nsmc-master/raw/101777.json
#   inflating: data/nsmc-master/raw/10178.json
#   inflating: data/nsmc-master/raw/101783.json
#   inflating: data/nsmc-master/raw/101784.json
#   inflating: data/nsmc-master/raw/101785.json
#   inflating: data/nsmc-master/raw/10180.json
#   inflating: data/nsmc-master/raw/10181.json
#   inflating: data/nsmc-master/raw/10182.json
#   inflating: data/nsmc-master/raw/10183.json
#   inflating: data/nsmc-master/raw/10184.json
#   inflating: data/nsmc-master/raw/10185.json
#   inflating: data/nsmc-master/raw/10186.json
#   inflating: data/nsmc-master/raw/101872.json
#   inflating: data/nsmc-master/raw/101880.json
#   inflating: data/nsmc-master/raw/101886.json
#   inflating: data/nsmc-master/raw/10189.json
#   inflating: data/nsmc-master/raw/101897.json
#   inflating: data/nsmc-master/raw/101898.json
#   inflating: data/nsmc-master/raw/10190.json
#   inflating: data/nsmc-master/raw/101901.json
#   inflating: data/nsmc-master/raw/101903.json
#   inflating: data/nsmc-master/raw/101906.json
#   inflating: data/nsmc-master/raw/101907.json
#   inflating: data/nsmc-master/raw/101908.json
#   inflating: data/nsmc-master/raw/101909.json
#   inflating: data/nsmc-master/raw/10191.json
#   inflating: data/nsmc-master/raw/10192.json
#   inflating: data/nsmc-master/raw/101929.json
#   inflating: data/nsmc-master/raw/10193.json
#   inflating: data/nsmc-master/raw/101934.json
#   inflating: data/nsmc-master/raw/101936.json
#   inflating: data/nsmc-master/raw/101937.json
#   inflating: data/nsmc-master/raw/101938.json
#   inflating: data/nsmc-master/raw/101939.json
#   inflating: data/nsmc-master/raw/10194.json
#   inflating: data/nsmc-master/raw/101948.json
#   inflating: data/nsmc-master/raw/101950.json
#   inflating: data/nsmc-master/raw/101953.json
#   inflating: data/nsmc-master/raw/101955.json
#   inflating: data/nsmc-master/raw/101960.json
#   inflating: data/nsmc-master/raw/97695.json
#   inflating: data/nsmc-master/raw/97696.json
#   inflating: data/nsmc-master/raw/97704.json
#   inflating: data/nsmc-master/raw/97706.json
#   inflating: data/nsmc-master/raw/97707.json
#   inflating: data/nsmc-master/raw/97711.json
#   inflating: data/nsmc-master/raw/97717.json
#   inflating: data/nsmc-master/raw/97720.json
#   inflating: data/nsmc-master/raw/97721.json
#   inflating: data/nsmc-master/raw/97726.json
#   inflating: data/nsmc-master/raw/97737.json
#   inflating: data/nsmc-master/raw/97738.json
#   inflating: data/nsmc-master/raw/97745.json
#   inflating: data/nsmc-master/raw/97746.json
#   inflating: data/nsmc-master/raw/97747.json
#   inflating: data/nsmc-master/raw/97757.json
#   inflating: data/nsmc-master/raw/97780.json
#   inflating: data/nsmc-master/raw/97781.json
#   inflating: data/nsmc-master/raw/97802.json
#   inflating: data/nsmc-master/raw/97816.json
#   inflating: data/nsmc-master/raw/97818.json
#   inflating: data/nsmc-master/raw/97820.json
#   inflating: data/nsmc-master/raw/97823.json
#   inflating: data/nsmc-master/raw/97826.json
#   inflating: data/nsmc-master/raw/97829.json
#   inflating: data/nsmc-master/raw/97854.json
#   inflating: data/nsmc-master/raw/97855.json
#   inflating: data/nsmc-master/raw/97856.json
#   inflating: data/nsmc-master/raw/97857.json
#   inflating: data/nsmc-master/raw/97858.json
#   inflating: data/nsmc-master/raw/97859.json
#   inflating: data/nsmc-master/raw/97885.json
#   inflating: data/nsmc-master/raw/97892.json
#   inflating: data/nsmc-master/raw/97896.json
#   inflating: data/nsmc-master/raw/97897.json
#   inflating: data/nsmc-master/raw/97926.json
#   inflating: data/nsmc-master/raw/97971.json
#   inflating: data/nsmc-master/raw/97972.json
#   inflating: data/nsmc-master/raw/97975.json
#   inflating: data/nsmc-master/raw/98057.json
#   inflating: data/nsmc-master/raw/98058.json
#   inflating: data/nsmc-master/raw/98059.json
#   inflating: data/nsmc-master/raw/98078.json
#   inflating: data/nsmc-master/raw/98087.json
#   inflating: data/nsmc-master/raw/98088.json
#   inflating: data/nsmc-master/raw/98090.json
#   inflating: data/nsmc-master/raw/98091.json
#   inflating: data/nsmc-master/raw/98092.json
#   inflating: data/nsmc-master/raw/98101.json
#   inflating: data/nsmc-master/raw/98107.json
#   inflating: data/nsmc-master/raw/98124.json
#   inflating: data/nsmc-master/raw/98125.json
#   inflating: data/nsmc-master/raw/98129.json
#   inflating: data/nsmc-master/raw/98130.json
#   inflating: data/nsmc-master/raw/98139.json
#   inflating: data/nsmc-master/raw/98140.json
#   inflating: data/nsmc-master/raw/98141.json
#   inflating: data/nsmc-master/raw/98142.json
#   inflating: data/nsmc-master/raw/98144.json
#   inflating: data/nsmc-master/raw/98146.json
#   inflating: data/nsmc-master/raw/98147.json
#   inflating: data/nsmc-master/raw/98148.json
#   inflating: data/nsmc-master/raw/98149.json
#   inflating: data/nsmc-master/raw/98154.json
#   inflating: data/nsmc-master/raw/98155.json
#   inflating: data/nsmc-master/raw/98159.json
#   inflating: data/nsmc-master/raw/98161.json
#   inflating: data/nsmc-master/raw/98162.json
#   inflating: data/nsmc-master/raw/98168.json
#   inflating: data/nsmc-master/raw/98169.json
#   inflating: data/nsmc-master/raw/98170.json
#   inflating: data/nsmc-master/raw/98171.json
#   inflating: data/nsmc-master/raw/98173.json
#   inflating: data/nsmc-master/raw/98174.json
#   inflating: data/nsmc-master/raw/98175.json
#   inflating: data/nsmc-master/raw/98186.json
#   inflating: data/nsmc-master/raw/98275.json
#   inflating: data/nsmc-master/raw/98276.json
#   inflating: data/nsmc-master/raw/98279.json
#   inflating: data/nsmc-master/raw/98280.json
#   inflating: data/nsmc-master/raw/98293.json
#   inflating: data/nsmc-master/raw/98381.json
#   inflating: data/nsmc-master/raw/98402.json
#   inflating: data/nsmc-master/raw/98403.json
#   inflating: data/nsmc-master/raw/98404.json
#   inflating: data/nsmc-master/raw/98417.json
#   inflating: data/nsmc-master/raw/98420.json
#   inflating: data/nsmc-master/raw/98428.json
#   inflating: data/nsmc-master/raw/98430.json
#   inflating: data/nsmc-master/raw/98432.json
#   inflating: data/nsmc-master/raw/98438.json
#   inflating: data/nsmc-master/raw/98445.json
#   inflating: data/nsmc-master/raw/98446.json
#   inflating: data/nsmc-master/raw/98447.json
#   inflating: data/nsmc-master/raw/98456.json
#   inflating: data/nsmc-master/raw/98467.json
#   inflating: data/nsmc-master/raw/98477.json
#   inflating: data/nsmc-master/raw/98481.json
#   inflating: data/nsmc-master/raw/98483.json
#   inflating: data/nsmc-master/raw/98484.json
#   inflating: data/nsmc-master/raw/98485.json
#   inflating: data/nsmc-master/raw/98487.json
#   inflating: data/nsmc-master/raw/98497.json
#   inflating: data/nsmc-master/raw/98504.json
#   inflating: data/nsmc-master/raw/98505.json
#   inflating: data/nsmc-master/raw/98506.json
#   inflating: data/nsmc-master/raw/98511.json
#   inflating: data/nsmc-master/raw/98513.json
#   inflating: data/nsmc-master/raw/98528.json
#   inflating: data/nsmc-master/raw/98544.json
#   inflating: data/nsmc-master/raw/98709.json
#   inflating: data/nsmc-master/raw/98718.json
#   inflating: data/nsmc-master/raw/98727.json
#   inflating: data/nsmc-master/raw/98728.json
#   inflating: data/nsmc-master/raw/98729.json
#   inflating: data/nsmc-master/raw/98738.json
#   inflating: data/nsmc-master/raw/98740.json
#   inflating: data/nsmc-master/raw/98742.json
#   inflating: data/nsmc-master/raw/98744.json
#   inflating: data/nsmc-master/raw/98747.json
#   inflating: data/nsmc-master/raw/98748.json
#   inflating: data/nsmc-master/raw/98749.json
#   inflating: data/nsmc-master/raw/98750.json
#   inflating: data/nsmc-master/raw/98756.json
#   inflating: data/nsmc-master/raw/98893.json
#   inflating: data/nsmc-master/raw/98903.json
#   inflating: data/nsmc-master/raw/98911.json
#   inflating: data/nsmc-master/raw/98917.json
#   inflating: data/nsmc-master/raw/98929.json
#   inflating: data/nsmc-master/raw/98945.json
#   inflating: data/nsmc-master/raw/98947.json
#   inflating: data/nsmc-master/raw/98952.json
#   inflating: data/nsmc-master/raw/98959.json
#   inflating: data/nsmc-master/raw/98967.json
#   inflating: data/nsmc-master/raw/98969.json
#   inflating: data/nsmc-master/raw/98970.json
#   inflating: data/nsmc-master/raw/98971.json
#   inflating: data/nsmc-master/raw/98982.json
#   inflating: data/nsmc-master/raw/98993.json
#   inflating: data/nsmc-master/raw/98996.json
#   inflating: data/nsmc-master/raw/98997.json
#   inflating: data/nsmc-master/raw/99073.json
#   inflating: data/nsmc-master/raw/99094.json
#   inflating: data/nsmc-master/raw/99096.json
#   inflating: data/nsmc-master/raw/99101.json
#   inflating: data/nsmc-master/raw/99106.json
#   inflating: data/nsmc-master/raw/99107.json
#   inflating: data/nsmc-master/raw/99111.json
#   inflating: data/nsmc-master/raw/99134.json
#   inflating: data/nsmc-master/raw/99148.json
#   inflating: data/nsmc-master/raw/99150.json
#   inflating: data/nsmc-master/raw/99155.json
#   inflating: data/nsmc-master/raw/99314.json
#   inflating: data/nsmc-master/raw/99327.json
#   inflating: data/nsmc-master/raw/99335.json
#   inflating: data/nsmc-master/raw/99338.json
#   inflating: data/nsmc-master/raw/99339.json
#   inflating: data/nsmc-master/raw/99344.json
#   inflating: data/nsmc-master/raw/99352.json
#   inflating: data/nsmc-master/raw/99353.json
#   inflating: data/nsmc-master/raw/99354.json
#   inflating: data/nsmc-master/raw/99355.json
#   inflating: data/nsmc-master/raw/99384.json
#   inflating: data/nsmc-master/raw/99385.json
#   inflating: data/nsmc-master/raw/99386.json
#   inflating: data/nsmc-master/raw/99391.json
#   inflating: data/nsmc-master/raw/99396.json
#   inflating: data/nsmc-master/raw/99488.json
#   inflating: data/nsmc-master/raw/99566.json
#   inflating: data/nsmc-master/raw/99577.json
#   inflating: data/nsmc-master/raw/99615.json
#   inflating: data/nsmc-master/raw/99616.json
#   inflating: data/nsmc-master/raw/99621.json
#   inflating: data/nsmc-master/raw/99622.json
#   inflating: data/nsmc-master/raw/99625.json
#   inflating: data/nsmc-master/raw/99632.json
#   inflating: data/nsmc-master/raw/99633.json
#   inflating: data/nsmc-master/raw/99647.json
#   inflating: data/nsmc-master/raw/99648.json
#   inflating: data/nsmc-master/raw/99652.json
#   inflating: data/nsmc-master/raw/99653.json
#   inflating: data/nsmc-master/raw/99655.json
#   inflating: data/nsmc-master/raw/99660.json
#   inflating: data/nsmc-master/raw/99671.json
#   inflating: data/nsmc-master/raw/99705.json
#   inflating: data/nsmc-master/raw/99706.json
#   inflating: data/nsmc-master/raw/99707.json
#   inflating: data/nsmc-master/raw/99714.json
#   inflating: data/nsmc-master/raw/99716.json
#   inflating: data/nsmc-master/raw/99717.json
#   inflating: data/nsmc-master/raw/99722.json
#   inflating: data/nsmc-master/raw/99723.json
#   inflating: data/nsmc-master/raw/99724.json
#   inflating: data/nsmc-master/raw/99731.json
#   inflating: data/nsmc-master/raw/99738.json
#   inflating: data/nsmc-master/raw/99740.json
#   inflating: data/nsmc-master/raw/99741.json
#   inflating: data/nsmc-master/raw/99742.json
#   inflating: data/nsmc-master/raw/99745.json
#   inflating: data/nsmc-master/raw/99752.json
#   inflating: data/nsmc-master/raw/99759.json
#   inflating: data/nsmc-master/raw/99766.json
#   inflating: data/nsmc-master/raw/99769.json
#   inflating: data/nsmc-master/raw/99771.json
#   inflating: data/nsmc-master/raw/99773.json
#   inflating: data/nsmc-master/raw/99774.json
#   inflating: data/nsmc-master/raw/99775.json
#   inflating: data/nsmc-master/raw/99778.json
#   inflating: data/nsmc-master/raw/99792.json
#   inflating: data/nsmc-master/raw/99794.json
#   inflating: data/nsmc-master/raw/99797.json
#   inflating: data/nsmc-master/raw/99799.json
#   inflating: data/nsmc-master/raw/99800.json
#   inflating: data/nsmc-master/raw/99809.json
#   inflating: data/nsmc-master/raw/99828.json
#   inflating: data/nsmc-master/raw/99876.json
#   inflating: data/nsmc-master/synopses.json

# %%
import pandas as pd

# 데이터를 읽어봅시다. 
train_data = pd.read_table('~/aiffel/data/nsmc-master/ratings_train.txt')
test_data = pd.read_table('~/aiffel/data/nsmc-master/ratings_test.txt')

train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# ### Load Data function

# %%
# data loader
# 데이터 중복 제거, NaN 결측치 제거, 한국어 토크나이저 토큰화, 불용어 제거
# 사전 word_to_index 구성
# x_train, y_train, x_test, y_test, word_to_index 리턴
from collections import Counter
from konlpy.tag import Mecab
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

    
# konlpy tokenizer
# tokenizer = Mecab()
# 불용어
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# 데이터 불러오는 함수
def load_data(train_data, test_data, num_words=10000, tokenizer=Mecab()):
    # 중복 제거 및 Nan값 제거
    train_data.drop_duplicates(subset=['document'], inplace=True)
    train_data = train_data.dropna(how = 'any') 
    test_data.drop_duplicates(subset=['document'], inplace=True)
    test_data = test_data.dropna(how = 'any') 
    
    # 토콘화 및 불용어 제거 - 이부분만 sentence piece로 바뀌면 되는거 아닌가요
    X_train = []
    for sentence in train_data['document']:
        temp_X = tokenizer.pos(sentence) # 토큰화
        temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
        X_train.append(temp_X)

    X_test = []
    for sentence in test_data['document']:
        temp_X = tokenizer.pos(sentence) # 토큰화
        temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
        X_test.append(temp_X)
    
    # X_train을 list로 만들어서 word에 들어 있는 text를 하나로 합친다
    words = [word for sublist in X_train for word in sublist]
    
    # Counter로 가장 빈도가 높은 단어 추출 10000-4만큼 (용어, count(용어))
    counter = Counter(words)
    counter = counter.most_common(10000-4)
    vocab = ['', '', '', ''] + [key for key, _ in counter]
    # 빈도 높은 단어로 word index 사전 만들기
    word_to_index = {word:index for index, word in enumerate(vocab)}
     
    # word 리스트를 인자로 받았을 때 index리스트로 변환해줌    
    def wordlist_to_indexlist(wordlist):
        return [word_to_index[word] if word in word_to_index else word_to_index[''] for word in wordlist]
        
    X_train = list(map(wordlist_to_indexlist, X_train))
    X_test = list(map(wordlist_to_indexlist, X_test))
    
    # X_train. y_train, X_test , y_test
    return X_train, np.array(list(train_data['label'])), X_test, np.array(list(test_data['label'])), word_to_index

# %%
# 모든 문장은 Bos로 시작
# 단어 인덱스 리스트로 변환해주는 함수
def get_encoded_sentence(sentence,word_to_index):
    return [word_to_indexp['<BOS>']]+[word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in sentences.split() ]


# 여러 문장 리스트를 한번에 encode
def get_encoded_sentences(sentences, word_to_index):
    return [get_encoded_sentence(sentence,word_to_index) for sentence in sentences]
# 변수에 담아서 출력하면 [[list 형태의 문장 index가  출력됨]]

def get_decoded_sentences(encoded_sentences, index_to_word):
    return [get_decoded_sentence(encoded_sentence, index_to_word) for encoded in encoded_sentences]


# 앞문장 BoS는 제거해주고, index가 index_to word에 없으면 Unkown으로 처리
def get_decoded_sentence(encoded_sentence, index_to_word):
    return ' '.join(index_to_word[index] if index in index_to_word else '<UNK>' for index in encoded_sentence[1:])  #[1:

# %% [markdown]
# ### Train,Test data, word2index

# %%
# Hannanum
from konlpy.tag import Hannanum
# Kkma
from konlpy.tag import Kkma
# Komoran
from konlpy.tag import Komoran
# Mecab
from konlpy.tag import Mecab
from konlpy.tag import Okt


tokenizer_list = [Hannanum(),Kkma(),Komoran(),Mecab(),Okt()]

# 데이터 load_data함수 사용해서 train, test, 데이터 만들기
X_train_h, y_train_h, X_test_h, y_test_h, word_to_index_h = load_data(train_data, test_data,
                                                            tokenizer_list[0])
X_train_K, y_train_K, X_test_K, y_test_K, word_to_index_K = load_data(train_data, test_data,
                                                            tokenizer_list[1])
X_train_komo, y_train_komo, X_test_komo, y_test_komo, word_to_index_komo = load_data(train_data, test_data,
                                                            tokenizer_list[2])
X_train_Me, y_train_Me, X_test_Me, y_test_Me, word_to_index_Me = load_data(train_data, test_data,
                                                            tokenizer_list[3])
X_train_Ok, y_train_Ok, X_test_Ok, y_test_Ok, word_to_index_Ok = load_data(train_data, test_data,
                                                            tokenizer_list[4])

# %%
def word_to_index(word_to_index):
    # 실제 인코딩 인덱스는 제공된 word_to_index 기준으로 3씩 뒤로 밀려 있다
    word_to_index ={k:(v+3) for k,v in word_to_index.items()}

    # Hannanum
    # 처음 몇개의 인덱스는 사전 정의
    word_to_index["<PAD>"] = 0
    word_to_index["<BOS>"] = 1
    word_to_index["<UNK>"] = 2
    word_to_index["<UNUSED>"] = 3
    index_to_word = {index:word for word, index in word_to_index.items()}
    
    return word_to_index, index_to_word


# Hannanum
word_to_index_h,index_to_word_h = word_to_index(word_to_index_h)
#Okt
word_to_index_Ok,index_to_word_Ok = word_to_index(word_to_index_Ok)
#KKma
word_to_index_K,index_to_word_K = word_to_index(word_to_index_K)
#Komoran 
word_to_index_komo,index_to_word_komo = word_to_index(word_to_index_komo)
#Mecab 
word_to_index_Me,index_to_word_Me = word_to_index(word_to_index_Me)

# %% [markdown]
# ### Hannanum, Kkma, Komoran, Mecab, Okt

# %%
# maxlen 
def set_max_len(X_train,X_test,tokenizer_name):
    total_data_text = list(X_train) + list(X_test)
    # 텍스트데이터 문장길이의 리스트를 생성한 후
    num_tokens = [len(tokens) for tokens in total_data_text]
    num_tokens = np.array(num_tokens)
    # 문장길이의 평균값, 최대값, 표준편차를 계산해 본다. 
    
    print("===========================================================================")
    print(tokenizer_name)
    print('문장길이 평균 : ', np.mean(num_tokens))
    print('문장길이 최대 : ', np.max(num_tokens))
    print('문장길이 표준편차 : ', np.std(num_tokens))

    # 예를들어, 최대 길이를 (평균 + 2*표준편차)로 한다면,  
    max_tokens = np.mean(num_tokens) + 2 * np.std(num_tokens)
    maxlen = int(max_tokens)
    print('pad_sequences maxlen : ', maxlen)
    print(f'전체 문장의 {np.sum(num_tokens < max_tokens) / len(num_tokens)}%가 maxlen 설정값 이내에 포함됩니다.')
    
    return maxlen


maxlen = set_max_len(X_train_h,X_test_h,"Hannanum")
maxlen_k = set_max_len(X_train_K,X_test_K,"Kkma")
maxlen_komo = set_max_len(X_train_komo,X_test_komo,"Komoran")
maxlen_Me = set_max_len(X_train_Me,X_test_Me,"Mecab")
maxlen_Ok = set_max_len(X_train_Ok,X_test_Ok,"Okt")
# Out:
# ===========================================================================
# Hannanum
# 문장길이 평균 :  18.72297390690031
# 문장길이 최대 :  116
# 문장길이 표준편차 :  15.329503337998032
# pad_sequences maxlen :  49
# 전체 문장의 0.9346725436292804%가 maxlen 설정값 이내에 포함됩니다.
# ===========================================================================
# Kkma
# 문장길이 평균 :  18.72297390690031
# 문장길이 최대 :  116
# 문장길이 표준편차 :  15.329503337998032
# pad_sequences maxlen :  49
# 전체 문장의 0.9346725436292804%가 maxlen 설정값 이내에 포함됩니다.
# ===========================================================================
# Komoran
# 문장길이 평균 :  18.72297390690031
# 문장길이 최대 :  116
# 문장길이 표준편차 :  15.329503337998032
# pad_sequences maxlen :  49
# 전체 문장의 0.9346725436292804%가 maxlen 설정값 이내에 포함됩니다.
# ===========================================================================
# Mecab
# 문장길이 평균 :  18.72297390690031
# 문장길이 최대 :  116
# 문장길이 표준편차 :  15.329503337998032
# pad_sequences maxlen :  49
# 전체 문장의 0.9346725436292804%가 maxlen 설정값 이내에 포함됩니다.
# ===========================================================================
# Okt
# 문장길이 평균 :  18.72297390690031
# 문장길이 최대 :  116
# 문장길이 표준편차 :  15.329503337998032
# pad_sequences maxlen :  49
# 전체 문장의 0.9346725436292804%가 maxlen 설정값 이내에 포함됩니다.

# %%
# padding 처리
import tensorflow as tf

def padding_data(X_train,X_test,maxlen):
    x_train = tf.keras.preprocessing.sequence.pad_sequences(X_train,
                                                            value=word_to_index_h["<PAD>"],
                                                            padding='post', # 혹은 'pre'
                                                            maxlen=maxlen)

    x_test = tf.keras.preprocessing.sequence.pad_sequences(X_test,
                                                           value=word_to_index_h["<PAD>"],
                                                           padding='post', # 혹은 'pre'
                                                           maxlen=maxlen)
    return x_train, x_test
    

# paddding은 post로 진행
x_train_h, x_test_h = padding_data(X_train_h, X_test_h,maxlen)
x_train_K, x_test_K = padding_data(X_train_K, X_test_K,maxlen_k)
x_train_komo, x_test_komo = padding_data(X_train_komo, X_test_komo,maxlen_komo)
x_train_Ok, x_test_Ok = padding_data(X_train_Ok, X_test_Ok,maxlen_Ok)
x_train_Me, x_test_Me = padding_data(X_train_Me, X_test_Me,maxlen_Me)

print(x_train_h.shape)
print(x_train_K.shape)
print(x_train_komo.shape)
print(x_train_Ok.shape)
print(x_train_Me.shape)
# Out:
# (146182, 49)
# (146182, 49)
# (146182, 49)
# (146182, 49)
# (146182, 49)

# %% [markdown]
# ### LSTM Model

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))

class BiLSTMModel(tf.keras.Model):
    def __init__(self, vocab_size, word_vector_dim):
        super(BiLSTMModel, self).__init__()
        

        self.embedding_layer = tf.keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,))
        self.lstm_layer1 = tf.keras.layers.LSTM(128, dropout=0.3, recurrent_dropout=0.2, return_sequences=True)
        self.lstm_layer2 = tf.keras.layers.LSTM(128, dropout=0.5)
        self.dense_layer = tf.keras.layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.embedding_layer(inputs)
        x = self.lstm_layer1(x)
        x = self.lstm_layer2(x)
        outputs = self.dense_layer(x)
        return outputs

# Create an instance of the BiLSTMModel
vocab_size = 10000
word_vector_dim = 250

model_h = BiLSTMModel(vocab_size, word_vector_dim)
model_Me = BiLSTMModel(vocab_size, word_vector_dim)
model_Ok = BiLSTMModel(vocab_size, word_vector_dim)
model_K = BiLSTMModel(vocab_size, word_vector_dim)
model_komo = BiLSTMModel(vocab_size, word_vector_dim)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING:tensorflow:Layer lstm_54 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_56 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_58 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_60 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_62 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ### 훈련 데이터 만들기

# %%
# hannanum
# validation set 10000건 분리
x_val_h = x_train_h[:26182]   
y_val_h = y_train_h[:26182]

# validation set을 제외한 나머지 15000건
partial_x_train_h = x_train_h[26182:]  
partial_y_train_h = y_train_h[26182:]

print("hannanum")
print(partial_x_train_h.shape)
print(partial_y_train_h.shape)

# OKt
# validation set 10000건 분리
x_val_Ok = x_train_Ok[:26182]   
y_val_Ok = y_train_Ok[:26182]

# validation set을 제외한 나머지 15000건
partial_x_train_Ok = x_train_Ok[26182:]  
partial_y_train_Ok = y_train_Ok[26182:]

print("Okt")
print(partial_x_train_Ok.shape)
print(partial_y_train_Ok.shape)


# Komoran
# validation set 10000건 분리
x_val_komo = x_train_komo[:26182]   
y_val_komo = y_train_komo[:26182]

# validation set을 제외한 나머지 15000건
partial_x_train_komo = x_train_komo[26182:]  
partial_y_train_komo = y_train_komo[26182:]


print("Komoran")
print(partial_x_train_komo.shape)
print(partial_y_train_komo.shape)



# Mecab
# validation set 10000건 분리
x_val_Me = x_train_Me[:26182]   
y_val_Me = y_train_Me[:26182]

# validation set을 제외한 나머지 15000건
partial_x_train_Me = x_train_Me[26182:]  
partial_y_train_Me = y_train_Me[26182:]
print("Mecab")
print(partial_x_train_Me.shape)
print(partial_y_train_Me.shape)

# Kkma
# validation set 10000건 분리
x_val_K = x_train_K[:26182]   
y_val_K = y_train_K[:26182]

# validation set을 제외한 나머지 15000건
partial_x_train_K = x_train_K[26182:]  
partial_y_train_K = y_train_K[26182:]

print("kkma")
print(partial_x_train_K.shape)
print(partial_y_train_K.shape)
# Out:
# hannanum
# (120000, 49)
# (120000,)
# Okt
# (120000, 49)
# (120000,)
# Komoran
# (120000, 49)
# (120000,)
# Mecab
# (120000, 49)
# (120000,)
# kkma
# (120000, 49)
# (120000,)

# %% [markdown]
# ### Training

# %%
# 최적화 함수 Adam, RMSprops
opt = tf.keras.optimizers.Adam()

# 손실함수 binary_crossentropy 사용
model_h.compile(optimizer=opt, # 'adam'
              loss='binary_crossentropy',
              metrics=['accuracy'])

# 손실함수 binary_crossentropy 사용
model_Me.compile(optimizer=opt, # 'adam'
              loss='binary_crossentropy',
              metrics=['accuracy'])
# 손실함수 binary_crossentropy 사용
model_Ok.compile(optimizer=opt, # 'adam'
              loss='binary_crossentropy',
              metrics=['accuracy'])
# 손실함수 binary_crossentropy 사용
model_K.compile(optimizer=opt, # 'adam'
              loss='binary_crossentropy',
              metrics=['accuracy'])
# 손실함수 binary_crossentropy 사용
model_komo.compile(optimizer=opt, # 'adam'
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
epochs=5  # 몇 epoch를 훈련하면 좋을지 결과를 보면서 바꾸어 봅시다. 

#hannanum
history_h = model_h.fit(partial_x_train_h,
                    partial_y_train_h,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val_h, y_val_h),
                    verbose=1)
#Mecab
history_Me = model_Me.fit(partial_x_train_Me,
                    partial_y_train_Me,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val_Me, y_val_Me),
                    verbose=1)
#OKt
history_Ok = model_Ok.fit(partial_x_train_Ok,
                    partial_y_train_Ok,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val_Ok, y_val_Ok),
                    verbose=1)
#Kkma
history_k = model_K.fit(partial_x_train_K,
                    partial_y_train_K,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val_K, y_val_K),
                    verbose=1)
# komoran
history_komo = model_komo.fit(partial_x_train_komo,
                    partial_y_train_komo,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val_komo, y_val_komo),
                    verbose=1)
# Out:
# Epoch 1/5
# 235/235 [==============================] - 54s 217ms/step - loss: 0.4722 - accuracy: 0.7458 - val_loss: 0.3557 - val_accuracy: 0.8455
# Epoch 2/5
# 235/235 [==============================] - 50s 214ms/step - loss: 0.3257 - accuracy: 0.8608 - val_loss: 0.3309 - val_accuracy: 0.8569
# Epoch 3/5
# 235/235 [==============================] - 50s 213ms/step - loss: 0.2911 - accuracy: 0.8770 - val_loss: 0.3539 - val_accuracy: 0.8548
# Epoch 4/5
# 235/235 [==============================] - 50s 213ms/step - loss: 0.2606 - accuracy: 0.8904 - val_loss: 0.3240 - val_accuracy: 0.8628
# Epoch 5/5
# 235/235 [==============================] - 50s 214ms/step - loss: 0.2391 - accuracy: 0.9012 - val_loss: 0.3701 - val_accuracy: 0.8582
# Epoch 1/5
# 235/235 [==============================] - 55s 218ms/step - loss: 0.5235 - accuracy: 0.7103 - val_loss: 0.3781 - val_accuracy: 0.8389
# Epoch 2/5
# 235/235 [==============================] - 51s 216ms/step - loss: 0.3271 - accuracy: 0.8622 - val_loss: 0.3244 - val_accuracy: 0.8625
# Epoch 3/5
# 235/235 [==============================] - 51s 216ms/step - loss: 0.2761 - accuracy: 0.8852 - val_loss: 0.3156 - val_accuracy: 0.8676
# Epoch 4/5
# 235/235 [==============================] - 50s 214ms/step - loss: 0.2445 - accuracy: 0.8993 - val_loss: 0.3228 - val_accuracy: 0.8658
# Epoch 5/5
# 235/235 [==============================] - 51s 216ms/step - loss: 0.2182 - accuracy: 0.9121 - val_loss: 0.3481 - val_accuracy: 0.8625
# Epoch 1/5
# 235/235 [==============================] - 57s 227ms/step - loss: 0.6280 - accuracy: 0.6539 - val_loss: 0.6232 - val_accuracy: 0.6875
# Epoch 2/5
# 235/235 [==============================] - 51s 216ms/step - loss: 0.6053 - accuracy: 0.6864 - val_loss: 0.5739 - val_accuracy: 0.7032
# Epoch 3/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.5084 - accuracy: 0.7525 - val_loss: 0.5009 - val_accuracy: 0.7473
# Epoch 4/5
# 235/235 [==============================] - 50s 215ms/step - loss: 0.3895 - accuracy: 0.8202 - val_loss: 0.3431 - val_accuracy: 0.8542
# Epoch 5/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.3021 - accuracy: 0.8750 - val_loss: 0.3325 - val_accuracy: 0.8597
# Epoch 1/5
# 235/235 [==============================] - 56s 224ms/step - loss: 0.6170 - accuracy: 0.6586 - val_loss: 0.5249 - val_accuracy: 0.7734
# Epoch 2/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.4984 - accuracy: 0.7810 - val_loss: 0.4014 - val_accuracy: 0.8221
# Epoch 3/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.3566 - accuracy: 0.8469 - val_loss: 0.3510 - val_accuracy: 0.8506
# Epoch 4/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.3062 - accuracy: 0.8713 - val_loss: 0.3383 - val_accuracy: 0.8592
# Epoch 5/5
# 235/235 [==============================] - 50s 214ms/step - loss: 0.2723 - accuracy: 0.8859 - val_loss: 0.3485 - val_accuracy: 0.8599
# Epoch 1/5
# 235/235 [==============================] - 55s 218ms/step - loss: 0.4598 - accuracy: 0.7746 - val_loss: 0.3439 - val_accuracy: 0.8569
# Epoch 2/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.3041 - accuracy: 0.8719 - val_loss: 0.3232 - val_accuracy: 0.8613
# Epoch 3/5
# 235/235 [==============================] - 51s 216ms/step - loss: 0.2613 - accuracy: 0.8916 - val_loss: 0.3256 - val_accuracy: 0.8654
# Epoch 4/5
# 235/235 [==============================] - 50s 215ms/step - loss: 0.2350 - accuracy: 0.9043 - val_loss: 0.3484 - val_accuracy: 0.8633
# Epoch 5/5
# 235/235 [==============================] - 51s 215ms/step - loss: 0.2119 - accuracy: 0.9146 - val_loss: 0.3660 - val_accuracy: 0.8628

# %% [markdown]
# ### Various Tokenizer Training Result

# %%
history_dict_h = history_h.history
history_dict_k = history_k.history
history_dict_me = history_Me.history
history_dict_komo = history_komo.history
history_dict_ok = history_Ok.history

# %%
# 손실함수 그래프 확인
import matplotlib.pyplot as plt

#acc = history_dict['accuracy']
#val_acc = history_dict['val_accuracy']
#loss = history_dict['loss']
#val_loss = history_dict['val_loss']

epochs = range(1, 5 + 1)

# "bo"는 "파란색 점"입니다
#plt.plot(epochs, loss, 'bo', label='Training loss')
# b는 "파란 실선"입니다
plt.plot(epochs, history_dict_h['val_loss'],  label='Hananum Validation loss')
plt.plot(epochs, history_dict_k['val_loss'], label='Kkma Validation loss')
plt.plot(epochs, history_dict_me['val_loss'],  label='Mecab Validation loss')
plt.plot(epochs, history_dict_komo['val_loss'], label='komoran Validation loss')
plt.plot(epochs, history_dict_ok['val_loss'],  label='Okt Validation loss')

plt.title('Various Tokenizer validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
epochs = range(1,5+ 1)

# "bo"는 "파란색 점"입니다
#plt.plot(epochs, loss, 'bo', label='Training loss')
# b는 "파란 실선"입니다
plt.plot(epochs, history_dict_h['val_accuracy'],  label='Hananum Validation accuracy')
plt.plot(epochs, history_dict_k['val_accuracy'], label='Kkma Validation accuracy')
plt.plot(epochs, history_dict_me['val_accuracy'],  label='Mecab Validation accuracy')
plt.plot(epochs, history_dict_komo['val_accuracy'], label='komoran Validation accuracy')
plt.plot(epochs, history_dict_ok['val_accuracy'],  label='Okt Validation accuracy')

plt.title('Various Tokenizer validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()

plt.show()

# %% [markdown]
# - 결과적으로 Kkma 가장 좋은 성능을 보였고, 그 다음으로 Mecab이 좋은 성능을 보였다
# - accuracy는 Kkma이 조금 더 좋았으나 loss 값은 Mecab이 훨씬 낮게 나왔다.
# - OKt가 가장 안좋은 성능을 보였다
# - 아마도 okt로 tokenize한 값들이..... 모호했나..

# %% [markdown]
# ### SentencePiece

# %%
def sp_tokenize(s, corpus): 

    tensor = []
    
    # corpus 문장 말뭉치 - 온전한 문장의 list 전달
    for sen in corpus:
        tensor.append(s.EncodeAsIds(sen))

    with open("./korean_spm.vocab", 'r') as f:
        vocab = f.readlines()

    word_index = {}
    index_word = {}

    for idx, line in enumerate(vocab):
        word = line.split("\t")[0]

        word_index.update({word:idx})
        index_word.update({idx:word})
    
    # padding 처리
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post', maxlen = 47)

    return tensor, word_index, index_word

# %%
# sentencePiece Unigram Mode

s = spm.SentencePieceProcessor()
s.Load('korean_spm.model')

# SentencePiece를 활용한 sentence -> encoding
tokensIDs = s.EncodeAsIds('아버지가방에들어가신다.')
print(tokensIDs)

# SentencePiece를 활용한 sentence -> encoded pieces
print(s.SampleEncodeAsPieces('아버지가방에들어가신다.',1, 0.0))

# SentencePiece를 활용한 encoding -> sentence 복원
print(s.DecodeIds(tokensIDs))
# Out:
# [1243, 11, 302, 7, 3608, 11, 287, 38, 3]
# ['▁아버지', '가', '방', '에', '들어', '가', '신', '다', '.']
# 아버지가방에들어가신다.

# %%
# sentencePiece Bpe Mode

s_bpe = spm.SentencePieceProcessor()
s_bpe.Load('korean_spm_bpe.model')

# SentencePiece를 활용한 sentence -> encoding
tokensIDs = s_bpe.EncodeAsIds('아버지가방에들어가신다.')
print(tokensIDs)

# SentencePiece를 활용한 sentence -> encoded pieces
print(s_bpe.SampleEncodeAsPieces('아버지가방에들어가신다.',1, 0.0))

# SentencePiece를 활용한 encoding -> sentence 복원
print(s_bpe.DecodeIds(tokensIDs))
# Out:
# [1520, 1154, 6614, 6710, 2644, 6782, 6685, 6687]
# ['▁아버', '지가', '방에', '들', '어가', '신', '다', '.']
# 아버지가방에들어가신다.

# %% [markdown]
# - Bpe보다 unigram이 의미가 있는 작은 단어로 더 잘 쪼개진 것으로 보인다

# %%
train_data = pd.read_table('~/aiffel/data/nsmc-master/ratings.txt')
train_data.head()
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1

# %%
from sklearn.model_selection import train_test_split

# 데이터 불러오는 함수
def load_data(train_data, s ):
    # 중복 제거 및 NaN값 제거
    train_data.drop_duplicates(subset=['document'], inplace=True)
    train_data = train_data.dropna(how='any')

    # SentencePiece Tokenization
    X_train, word_index, index_word = sp_tokenize(s, train_data['document'])
    X_train, X_val, y_train, y_val = train_test_split(X_train, train_data['label'], test_size=0.2, random_state=42)

    # X_train, y_train, X_test, y_test
    return X_train, X_val, y_train, y_val, word_index

# %%
len(X_train[0])
# Out:
# 47

# %%
# unigram sentence piece tokenizer
X_train, X_val, y_train, y_val, word_to_index = load_data(train_data, s)

vocab_size = len(word_to_index)
# 250
word_vector_dim = 250
model = BiLSTMModel(vocab_size, word_vector_dim)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# bpe sentence piece tokenizer
X_train, X_val, y_train, y_val, word_to_index = load_data(train_data, s_bpe)

vocab_size = len(word_to_index)
# 250
word_vector_dim = 250
model_bpe = BiLSTMModel(vocab_size, word_vector_dim)

model_bpe.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Layer lstm_42 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Train the model
epochs = 5
batch_size = 512
model.fit(np.array(X_train), y_train, 
          epochs=epochs, 
          batch_size=batch_size, 
          validation_data=(np.array(X_val), y_val))
# Out:
# Epoch 1/5
# 304/304 [==============================] - 71s 210ms/step - loss: 0.4648 - accuracy: 0.7714 - val_loss: 0.3977 - val_accuracy: 0.8187
# Epoch 2/5
# 304/304 [==============================] - 62s 205ms/step - loss: 0.3824 - accuracy: 0.8277 - val_loss: 0.3745 - val_accuracy: 0.8333
# Epoch 3/5
# 304/304 [==============================] - 62s 204ms/step - loss: 0.3463 - accuracy: 0.8461 - val_loss: 0.3749 - val_accuracy: 0.8371
# Epoch 4/5
# 304/304 [==============================] - 62s 204ms/step - loss: 0.3212 - accuracy: 0.8605 - val_loss: 0.3540 - val_accuracy: 0.8375
# Epoch 5/5
# 304/304 [==============================] - 62s 205ms/step - loss: 0.3024 - accuracy: 0.8711 - val_loss: 0.3557 - val_accuracy: 0.8414

# %%
results = model.evaluate(X_val,  y_val, verbose=2)
print(results)
# Out:
# 1216/1216 - 17s - loss: 0.3557 - accuracy: 0.8414
# [0.35566651821136475, 0.8414248824119568]

# %%
# Train the model
epochs = 5
batch_size = 512
history_bpe = model_bpe.fit(np.array(X_train), y_train, 
          epochs=epochs, 
          batch_size=batch_size, 
          validation_data=(np.array(X_val), y_val))
# Out:
# Epoch 1/5
# 304/304 [==============================] - 69s 210ms/step - loss: 0.4642 - accuracy: 0.7690 - val_loss: 0.4031 - val_accuracy: 0.8179
# Epoch 2/5
# 304/304 [==============================] - 64s 209ms/step - loss: 0.3809 - accuracy: 0.8290 - val_loss: 0.3858 - val_accuracy: 0.8275
# Epoch 3/5
# 304/304 [==============================] - 64s 209ms/step - loss: 0.3443 - accuracy: 0.8465 - val_loss: 0.3587 - val_accuracy: 0.8392
# Epoch 4/5
# 304/304 [==============================] - 64s 209ms/step - loss: 0.3198 - accuracy: 0.8604 - val_loss: 0.3561 - val_accuracy: 0.8412
# Epoch 5/5
# 304/304 [==============================] - 63s 208ms/step - loss: 0.2987 - accuracy: 0.8730 - val_loss: 0.3639 - val_accuracy: 0.8421

# %% [markdown]
# ### Unigram & BPE Result

# %%
history_dict_bpe = history_bpe.history

# 손실함수 그래프 확인
import matplotlib.pyplot as plt

epochs = range(1, 5+ 1)

plt.plot(epochs, history_dict_s['val_loss'],  label='unigram Validation loss')
plt.plot(epochs, history_dict_bpe['val_loss'],  label='bpe Validation loss')

plt.title('Unigram & BPE Sentence Piece validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()

plt.show()

# %%
history_dict_bpe = history_bpe.history

# 손실함수 그래프 확인
import matplotlib.pyplot as plt

epochs = range(1, 5+ 1)

plt.plot(epochs, history_dict_s['val_accuracy'],  label='unigram Validation accuracy')
plt.plot(epochs, history_dict_bpe['val_accuracy'],  label='bpe Validation accuracy')

plt.title('Unigram & BPE Sentence Piece validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')

plt.legend()

plt.show()

# %% [markdown]
# - unigram mode와 Bpe mode를 비교해보았을 때 큰 차이가 나지는 않지만 unigram이 더 성능이 좋게 나타났다.
# - 앞에 쪼갠 문장을 확인해보았을 때 unigram이 bpe보다 의미를 잘 보존한 작은 단위로 더 잘 쪼개졌기 때문이것 같다.

# %% [markdown]
# ### Tokenizer All

# %%
history_dict_s = history.history

# 손실함수 그래프 확인
import matplotlib.pyplot as plt

epochs = range(1, 5+ 1)

plt.plot(epochs, history_dict_s['val_loss'],  label='SP Validation loss')
plt.plot(epochs, history_dict_h['val_loss'],  label='Hananum Validation loss')
plt.plot(epochs, history_dict_k['val_loss'], label='Kkma Validation loss')
plt.plot(epochs, history_dict_me['val_loss'],  label='Mecab Validation loss')
plt.plot(epochs, history_dict_komo['val_loss'], label='komoran Validation loss')
plt.plot(epochs, history_dict_ok['val_loss'],  label='Okt Validation loss')

plt.title('Various Tokenizer validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()

plt.show()

# %%
history_dict_s = history.history

# 손실함수 그래프 확인
import matplotlib.pyplot as plt

epochs = range(1, 5+ 1)

plt.plot(epochs, history_dict_s['val_accuracy'],  label='SP Validation accuracy')
plt.plot(epochs, history_dict_h['val_accuracy'],  label='Hananum Validation accuracy')
plt.plot(epochs, history_dict_k['val_accuracy'], label='Kkma Validation accuracy')
plt.plot(epochs, history_dict_me['val_accuracy'],  label='Mecab Validation accuracy')
plt.plot(epochs, history_dict_komo['val_accuracy'], label='komoran Validation accuracy')
plt.plot(epochs, history_dict_ok['val_accuracy'],  label='Okt Validation accuracy')

plt.title('Various Tokenizer validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')

plt.legend()

plt.show()

# %% [markdown]
# - 결론적으로 sentencepiece를 사용한 모델의 성능이 더 높게 나타났다
# - Tokenizer를 변경했을 뿐인데 성능이 크게는 4%까지 차이가 났다.
# - 모델도 중요하지만 전처리하는 과정이 훨씬 더 많이 걸렸고, 언어라는 데이터 자체도 너무 모호해서 전처리하는 방식의 중요성을 배웠다..
